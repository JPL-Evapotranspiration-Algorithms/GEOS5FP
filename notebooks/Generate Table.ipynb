# %%
from ECOv002_calval_tables import load_times_locations
from GEOS5FP import GEOS5FP

# %%
GEOS5FP_connection = GEOS5FP()
GEOS5FP_connection
# Out:
# {
#   "URL": "https://portal.nccs.nasa.gov/datashare/gmao/geos-fp/das",
#   "download_directory": "~/data/GEOS5FP"
# }

# %%
targets_df = load_times_locations()
targets_df
# Out:
#           ID             time_UTC                  geometry
# 0     US-NC3  2019-10-02 19:09:40    POINT (-76.656 35.799)
# 1     US-Mi3  2019-06-23 18:17:17   POINT (-80.637 41.8222)
# 2     US-Mi3  2019-06-27 16:35:42   POINT (-80.637 41.8222)
# 3     US-Mi3  2019-06-30 15:44:10   POINT (-80.637 41.8222)
# 4     US-Mi3  2019-07-01 14:53:48   POINT (-80.637 41.8222)
# ...      ...                  ...                       ...
# 1060  US-xAE  2021-12-11 16:01:12  POINT (-99.0588 35.4106)
# 1061  US-xAE  2022-03-25 22:45:31  POINT (-99.0588 35.4106)
# 1062  US-xAE  2022-04-12 22:53:09  POINT (-99.0588 35.4106)
# 1063  US-xAE  2022-04-14 14:45:37  POINT (-99.0588 35.4106)
# 1064  US-xAE  2022-04-20 19:38:47  POINT (-99.0588 35.4106)
#
# [1065 rows x 3 columns]

# %%
sample_df = targets_df.sample(n=5)
sample_df
# Out:
#           ID             time_UTC                   geometry
# 194   US-SRM  2020-04-28 18:25:03  POINT (-110.8661 31.8214)
# 185   US-SRM  2019-10-01 21:28:22  POINT (-110.8661 31.8214)
# 107   US-Whs  2019-06-20 22:19:23  POINT (-110.0522 31.7438)
# 704   US-xJR  2021-12-11 15:59:28  POINT (-106.8425 32.5907)
# 1020  US-ARM  2020-10-01 20:25:40   POINT (-97.4888 36.6058)

# %%
results_df = GEOS5FP_connection.query(
    target_variables=["Ta_C", "RH"],
    targets_df=sample_df
)

results_df
# Out:
# [2025-11-25 12:20:46 INFO] Processing 5 spatio-temporal records at 4 unique coordinates (5 query batches)...
# [2025-11-25 12:20:46 INFO] Querying 3 variables (Ta, Q, PS) from tavg1_2d_slv_Nx at 4 coordinates (5 batches)...
# [2025-11-25 12:20:46 INFO]   Coordinate 1/4: (31.8214, -110.8661) - 2 records in 2 time clusters
# [2025-11-25 12:20:46 INFO]     Batch 1/5: cluster 1/2 - 1 records, 0.0 days (2019-10-01 to 2019-10-01)
# [2025-11-25 12:20:46 INFO] Querying 3 variables (Ta, Q, PS) from tavg1_2d_slv_Nx at 4 coordinates (5 batches)...
# [2025-11-25 12:20:46 INFO]   Coordinate 1/4: (31.8214, -110.8661) - 2 records in 2 time clusters
# [2025-11-25 12:20:46 INFO]     Batch 1/5: cluster 1/2 - 1 records, 0.0 days (2019-10-01 to 2019-10-01)
# [2025-11-25 12:20:50 INFO]     Batch 2/5: cluster 2/2 - 1 records, 0.0 days (2020-04-28 to 2020-04-28)
# [2025-11-25 12:20:50 INFO]     Batch 2/5: cluster 2/2 - 1 records, 0.0 days (2020-04-28 to 2020-04-28)
# [2025-11-25 12:20:54 INFO]   Coordinate 2/4: (31.7438, -110.0522) - 1 records in 1 time clusters
# [2025-11-25 12:20:54 INFO]     Batch 3/5: cluster 1/1 - 1 records, 0.0 days (2019-06-20 to 2019-06-20)
# [2025-11-25 12:20:54 INFO]   Coordinate 2/4: (31.7438, -110.0522) - 1 records in 1 time clusters
# [2025-11-25 12:20:54 INFO]     Batch 3/5: cluster 1/1 - 1 records, 0.0 days (2019-06-20 to 2019-06-20)
# [2025-11-25 12:20:57 INFO]   Coordinate 3/4: (32.5907, -106.8425) - 1 records in 1 time clusters
# [2025-11-25 12:20:57 INFO]     Batch 4/5: cluster 1/1 - 1 records, 0.0 days (2021-12-11 to 2021-12-11)
# [2025-11-25 12:20:57 INFO]   Coordinate 3/4: (32.5907, -106.8425) - 1 records in 1 time clusters
# [2025-11-25 12:20:57 INFO]     Batch 4/5: cluster 1/1 - 1 records, 0.0 days (2021-12-11 to 2021-12-11)
# [2025-11-25 12:21:01 INFO]   Coordinate 4/4: (36.6058, -97.4888) - 1 records in 1 time clusters
# [2025-11-25 12:21:01 INFO]     Batch 5/5: cluster 1/1 - 1 records, 0.0 days (2020-10-01 to 2020-10-01)
# [2025-11-25 12:21:01 INFO]   Coordinate 4/4: (36.6058, -97.4888) - 1 records in 1 time clusters
# [2025-11-25 12:21:01 INFO]     Batch 5/5: cluster 1/1 - 1 records, 0.0 days (2020-10-01 to 2020-10-01)
# [2025-11-25 12:21:05 INFO] Computing derived variables: Ta_C, RH
# [2025-11-25 12:21:05 INFO] Computing derived variables: Ta_C, RH
#           ID             time_UTC       Ta_C        RH  \
# 194   US-SRM  2020-04-28 18:25:03  30.723444  0.091621
# 185   US-SRM  2019-10-01 21:28:22  27.265344  0.313737
# 107   US-Whs  2019-06-20 22:19:23  34.769739  0.039071
# 704   US-xJR  2021-12-11 15:59:28   2.174036  0.260884
# 1020  US-ARM  2020-10-01 20:25:40  21.877771  0.217161
#
#                        geometry
# 194   POINT (-110.8661 31.8214)
# 185   POINT (-110.8661 31.8214)
# 107   POINT (-110.0522 31.7438)
# 704   POINT (-106.8425 32.5907)
# 1020   POINT (-97.4888 36.6058)
