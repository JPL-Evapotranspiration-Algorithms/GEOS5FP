# %%
from GEOS5FP import GEOS5FP
from sentinel_tiles import sentinel_tiles

# %%
geos5fp = GEOS5FP()
geos5fp
# Out:
# {
#   "URL": "https://portal.nccs.nasa.gov/datashare/gmao/geos-fp/das",
#   "download_directory": "~/data/GEOS5FP"
# }

# %%
geometry = sentinel_tiles.grid("11SPS")
geometry
# Out:
# {
#   "dimensions": {
#     "rows": 3660,
#     "cols": 3660
#   },
#   "bbox": {
#     "xmin": 600000.0,
#     "ymin": 3590220.0,
#     "xmax": 709800.0,
#     "ymax": 3700020.0
#   },
#   "crs": "EPSG:32611",
#   "resolution": {
#     "cell_width": 30.0,
#     "cell_height": -30.0
#   }
# }

# %%
Ta_C = geos5fp.Ta_C(time_UTC="2025-02-16 12:00:00", geometry=geometry, resampling="lanczos")
Ta_C
# Out:
# [2025-11-25 12:33:53 INFO] retrieving Ta from GEOS-5 FP tavg1_2d_slv_Nx T2M for 2025-02-16 12:00 UTC
# [2025-11-25 12:33:53 INFO] searching GEOS-5 FP tavg1_2d_slv_Nx at 2025-02-16 12:00:00 UTC
# [2025-11-25 12:33:53 INFO] checking existing file: ~/data/GEOS5FP/2025.02.16/GEOS.fp.asm.tavg1_2d_slv_Nx.20250216_1130.V01.nc4
# [2025-11-25 12:33:53 INFO] existing file is valid: ~/data/GEOS5FP/2025.02.16/GEOS.fp.asm.tavg1_2d_slv_Nx.20250216_1130.V01.nc4 (71.21 MB)
# [2025-11-25 12:33:54 INFO] checking existing file: ~/data/GEOS5FP/2025.02.16/GEOS.fp.asm.tavg1_2d_slv_Nx.20250216_1230.V01.nc4
# [2025-11-25 12:33:54 INFO] existing file is valid: ~/data/GEOS5FP/2025.02.16/GEOS.fp.asm.tavg1_2d_slv_Nx.20250216_1230.V01.nc4 (71.23 MB)
# [2025-11-25 12:33:54 INFO] interpolating GEOS-5 FP tavg1_2d_slv_Nx T2M from 2025-02-16 11:30 UTC and 2025-02-16 12:30 UTC to 2025-02-16 12:00 UTC
# ...

# %%
SM = geos5fp.SM(time_UTC="2025-02-14 12:00:00", geometry=geometry)
SM
# Out:
# [2025-11-25 12:32:19 INFO] retrieving top layer soil moisture from GEOS-5 FP tavg1_2d_lnd_Nx SFMC for 2025-02-14 12:00 UTC
# [2025-11-25 12:32:19 INFO] searching GEOS-5 FP tavg1_2d_lnd_Nx at 2025-02-14 12:00:00 UTC
# [2025-11-25 12:32:20 INFO] checking existing file: ~/data/GEOS5FP/2025.02.14/GEOS.fp.asm.tavg1_2d_lnd_Nx.20250214_1130.V01.nc4
# [2025-11-25 12:32:20 INFO] existing file is valid: ~/data/GEOS5FP/2025.02.14/GEOS.fp.asm.tavg1_2d_lnd_Nx.20250214_1130.V01.nc4 (31.52 MB)
# [2025-11-25 12:32:21 INFO] checking existing file: ~/data/GEOS5FP/2025.02.14/GEOS.fp.asm.tavg1_2d_lnd_Nx.20250214_1230.V01.nc4
# [2025-11-25 12:32:21 INFO] existing file is valid: ~/data/GEOS5FP/2025.02.14/GEOS.fp.asm.tavg1_2d_lnd_Nx.20250214_1230.V01.nc4 (31.52 MB)
# [2025-11-25 12:32:21 INFO] interpolating GEOS-5 FP tavg1_2d_lnd_Nx SFMC from 2025-02-14 11:30 UTC and 2025-02-14 12:30 UTC to 2025-02-14 12:00 UTC
# ...
